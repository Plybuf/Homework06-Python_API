# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer closer to the equator (0 Deg. Latitude). The difference between the Southern and Northern hemispheres is less than normal due to the time of year (early Fall). The temperatures at about 40 degrees North is a bit higher than at 40 degrees south, mostly due to the lingering absorbed energy that occurs immediately after the end of summer. The Southern Hemisphere is also mostly water, which moderates temperatures.
# * The relationship between latitude and cloudiness / humidity is not quite as strong as expected, but it is visible in the humidity scatterplot. Most of the earth's deserts are at about 30 degrees north and south of the equator due to the earth's natural wind patterns.  In the humidity plot, the lower humidity readings do tend to be more prevalent in these latitudes, but not as obvious as the temperature patterns.
# * Strong winds are typically associated with active storms are directly between strong low and high pressure systems. While there is not a strong correlation between the latitudes and wind speed, there IS a weak relationship between cloudiness and wind speed.  With the clustering of cloudiness at about 60 degrees north latitude and a group of high wind speeds at the same latitude, there are clearly a few active storms along this latitude.
#
# ---
#
# #### Note
# * Color ramps for Temperature and Wind Speed roughly follows the National Oceanic and Atmospheric Administration's (NOAA) guidelines.
# * The scatter plots have been flipped from the example provided.  This to view the city locations as they would fall on a map - with northern cities "up" on the plot and southern cities "down." Patterns related to latitude are easier to visualize if the user is familiar with viewing data on maps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Output File (CSV)
output_data_file = "../Outputs/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 601

# %%
#make sure I actually have cities in the list by glancing at the first 10.
print(cities[:10])
# Out:
# ['cambuci', 'puerto ayora', 'saskylakh', 'lagoa', 'ipixuna', 'mersing', 'lolua', 'okhotsk', 'rocha', 'tsihombe']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#set URL for openweather API and test to make sure everything works. remember to check units of measurement..
url = "http://api.openweathermap.org/data/2.5/weather?"

#set units
units = "imperial"

#partial query URL (just missing the city)
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=a42af216a12a652bf36173d00e1a0b7c&units=imperial&q='

# %%
#test that the query URL works correctly using one of the cities in the list earlier.
testcity = "kodiak"
response = requests.get(query_url + testcity).json()
response
# Out:
# {'coord': {'lon': -94.76, 'lat': 39.95},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 82.04,
#   'pressure': 1013,
#   'humidity': 62,
#   'temp_min': 82.04,
#   'temp_max': 82.04},
#  'visibility': 16093,
#  'wind': {'speed': 11.41, 'deg': 170},
#  'clouds': {'all': 1},
#  'dt': 1538524380,
#  'sys': {'type': 1,
#   'id': 1664,
#   'message': 0.0035,
#   'country': 'US',
#   'sunrise': 1538569043,
#   'sunset': 1538611077},
#  'id': 4407665,
#  'name': 'Kodiak',
#  'cod': 200}

# %% [markdown]
# #### Note the following variables needed to get the data for this homework:
# * LAT: 'coord.lat' for the latitude (getting this for dataframe makes it easier for exact value)
# * Name: 'name' for the name of the city
# * City number: 'id' for the city number (unique ID)
# * Temperature: 'main.temp'
# * Humidity: 'main.humidity'
# * Cloudiness: 'clouds.all' for cloudiness in %. Note 1 is 1%
# * Wind speed: 'wind.speed' for wind speed in mph

# %%
#create lists to store this information
lat = []
cityname = []
citynum = []
temp = []
humidity = []
cloudiness = []
windspeed = []

# %%
#test connection and generating lists. only run once to not overwhelm api and lock up my work.
#response = requests.get(query_url + "kodiak").json()
#lat.append(response['coord']['lat'])
#cityname.append(response['name'])
#citynum.append(response['id'])
#temp.append(response['main']['temp'])
#humidity.append(response['main']['humidity'])
#cloudiness.append(response['clouds']['all'])
#windspeed.append(response['wind']['speed'])
#print(f"The city number of {cityname} is '{citynum}'.")

# %%
#Now run for a second time to make sure that the append works.  Again, don't want to overwhelm and request too much.
#response = requests.get(query_url + "cairns").json()
#lat.append(response['coord']['lat'])
#cityname.append(response['name'])
#citynum.append(response['id'])
#temp.append(response['main']['temp'])
#humidity.append(response['main']['humidity'])
#cloudiness.append(response['clouds']['all'])
#windspeed.append(response['wind']['speed'])
#print(f"The city number of {cityname} is '{citynum}'.") #will adjust text to only show current values in loop

#now that this worked, I will comment out the last two sections and run the loop to avoid duplicate values.

# %%
#Now for the loop...
#create an iterative x to show how many requests are made.
x = 1
for city in cities:
    

    response = requests.get(query_url + city).json()
    
    if response['cod']==200:
        lat.append(response['coord']['lat'])
        cityname.append(response['name'])
        citynum.append(response['id'])
        temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        windspeed.append(response['wind']['speed'])
        print(f"Made request number: {x} for city: {city}")
        x = x+1
# Out:
# Made request number: 1 for city: cambuci
# Made request number: 2 for city: puerto ayora
# Made request number: 3 for city: saskylakh
# Made request number: 4 for city: lagoa
# Made request number: 5 for city: ipixuna
# Made request number: 6 for city: mersing
# Made request number: 7 for city: okhotsk
# Made request number: 8 for city: rocha
# Made request number: 9 for city: jamestown
# Made request number: 10 for city: cape town
# Made request number: 11 for city: cartagena
# Made request number: 12 for city: carnarvon
# Made request number: 13 for city: arraial do cabo
# Made request number: 14 for city: fortuna
# Made request number: 15 for city: ushuaia
# Made request number: 16 for city: georgetown
# Made request number: 17 for city: yellowknife
# Made request number: 18 for city: rikitea
# Made request number: 19 for city: oriximina
# Made request number: 20 for city: saldanha
# Made request number: 21 for city: lasa
# Made request number: 22 for city: mar del plata
# Made request number: 23 for city: comodoro rivadavia
# Made request number: 24 for city: pangnirtung
# Made request number: 25 for city: hasaki
# Made request number: 26 for city: port alfred
# Made request number: 27 for city: inhambane
# Made request number: 28 for city: lorengau
# Made request number: 29 for city: souillac
# Made request number: 30 for city: porto belo
# Made request number: 31 for city: ponta do sol
# Made request number: 32 for city: airai
# Made request number: 33 for city: skjervoy
# Made request number: 34 for city: khatanga
# Made request number: 35 for city: bethel
# Made request number: 36 for city: urengoy
# Made request number: 37 for city: mataura
# Made request number: 38 for city: haines junction
# Made request number: 39 for city: belen
# Made request number: 40 for city: punta arenas
# Made request number: 41 for city: hermanus
# Made request number: 42 for city: busselton
# Made request number: 43 for city: atuona
# Made request number: 44 for city: talnakh
# Made request number: 45 for city: kapaa
# Made request number: 46 for city: kodiak
# Made request number: 47 for city: zabol
# Made request number: 48 for city: bluff
# Made request number: 49 for city: bredasdorp
# Made request number: 50 for city: clyde river
# Made request number: 51 for city: karakol
# Made request number: 52 for city: hobart
# Made request number: 53 for city: barrow
# Made request number: 54 for city: dikson
# Made request number: 55 for city: jalu
# Made request number: 56 for city: nikolskoye
# Made request number: 57 for city: udachnyy
# Made request number: 58 for city: uruzgan
# Made request number: 59 for city: hilo
# Made request number: 60 for city: namatanai
# Made request number: 61 for city: new norfolk
# Made request number: 62 for city: straumen
# Made request number: 63 for city: penarroya-pueblonuevo
# Made request number: 533 for city: mandalgovi
# Made request number: 534 for city: ampanihy
# Made request number: 535 for city: nchelenge
# Made request number: 536 for city: rodney
# Made request number: 537 for city: vilhena
# Made request number: 538 for city: muyezerskiy
# Made request number: 539 for city: beberibe
# Made request number: 540 for city: port moresby
# Made request number: 541 for city: brae
# Made request number: 542 for city: hobyo
# Made request number: 543 for city: airdrie
# Made request number: 544 for city: maine-soroa
# Made request number: 545 for city: winnemucca

# %%
#create a dictionary from the results of the api call
weather_dict = {"latitude": lat, "City Name": cityname, "City Number": citynum, "Temperature": temp,
                "Humidity": humidity, "Cloudiness": cloudiness, "Wind Speed": windspeed}

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create the dataframe from the dictionary & spit out the CSV file

weather_frame = pd.DataFrame(weather_dict)

weather_frame.to_csv(output_data_file, index=False)

# %%
#show top results...
weather_frame.head()
# Out:
#    latitude     City Name  City Number  Temperature  Humidity  Cloudiness  \
# 0    -21.57       Cambuci      3467962        68.32        96          12
# 1     -0.74  Puerto Ayora      3652764        75.20        69          75
# 2     71.97     Saskylakh      2017155        22.60        89          68
# 3     37.14         Lagoa      2267254        69.80        94          40
# 4     -1.76       Ipixuna      3408424        78.80        83          20
#
#    Wind Speed
# 0        2.39
# 1        5.82
# 2        3.29
# 3        6.93
# 4       10.29

# %% [markdown]
# ### Plotting the Data
#
# NOTE: Unlike the starter code, all scatterplots will have the latitude on the Y axis.  This will allow the city positions North/South to make more sense visually

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_frame["Temperature"], weather_frame["latitude"], marker = "o", linewidth = 0.4, edgecolors = "black", c=weather_frame["Temperature"], cmap="RdYlBu_r", alpha=0.5)

plt.title("City Latitude vs. Current Temperature (10/2/2018)")
plt.ylabel("Latitude")
plt.xlabel("Current Temperature (F)")
plt.grid(axis = "both")

#show the color bar next to the scatterplot
plt.colorbar()

#save figure
plt.savefig("../Outputs/Lat_Temp.png")

#show the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_frame["Humidity"], weather_frame["latitude"], marker = "o", linewidth = 0.4, edgecolors = "black", c=weather_frame["Humidity"], cmap="Blues", alpha=0.5)

plt.title("City Latitude vs. Current Humidity (10/2/2018)")
plt.ylabel("Latitude")
plt.xlabel("Current Relative Humidity (%)")
plt.grid(axis = "both")

#show the color bar next to the scatterplot
plt.colorbar()

#save figure
plt.savefig("../Outputs/Lat_Humidity.png")

#show the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_frame["Cloudiness"], weather_frame["latitude"], marker = "o", linewidth = 0.4, edgecolors = "black", c=weather_frame["Cloudiness"], cmap="Greys", alpha=0.5)

plt.title("City Latitude vs. Current Cloudiness (10/2/2018)")
plt.ylabel("Latitude")
plt.xlabel("Current Cloudiness (%)")
plt.grid(axis = "both")

#show the color bar next to the scatterplot
plt.colorbar()

#save figure
plt.savefig("../Outputs/Lat_Cloudiness.png")

#show the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_frame["Wind Speed"], weather_frame["latitude"], marker = "o", linewidth = 0.4, edgecolors = "black", c=weather_frame["Wind Speed"], cmap="brg_r", alpha=0.5)

plt.title("City Latitude vs. Current Wind Speed (10/2/2018)")
plt.ylabel("Latitude")
plt.xlabel("Current Wind Speed (mph)")
plt.grid(axis = "both")

#show the color bar next to the scatterplot
plt.colorbar()

#save figure
plt.savefig("../Outputs/Lat_WindSpeed.png")

#show the plot
plt.show()
